# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F, types as T
from pyspark.sql.window import Window
from pyspark import StorageLevel
import os

spark = (SparkSession.builder
         .appName("Orders-ETL-All-In-One")
         .config("spark.sql.shuffle.partitions", "200")    # tune per cluster
         .config("spark.sql.adaptive.enabled", "true")     # AQE helps at scale
         .getOrCreate())


def resolve_input_path(user_override=None):
    candidates = []
    if user_override:
        candidates.append(user_override)


    candidates += [
        "orders_raw.csv",
        "./orders_raw.csv",
        "/content/orders_raw.csv",
    ]


    candidates += [
        "/dbfs/FileStore/orders_raw.csv",
        "dbfs:/FileStore/orders_raw.csv",
    ]


    for p in candidates:
        if p.startswith("dbfs:"):
            continue
        if os.path.exists(p):
            return p


    try:
        dbutils
        try:
            _ = dbutils.fs.head("dbfs:/FileStore/orders_raw.csv", 1)  # type: ignore
            return "dbfs:/FileStore/orders_raw.csv"
        except Exception:
            pass
    except NameError:
        pass

    return None


USER_INPUT_PATH = None

input_path = resolve_input_path(USER_INPUT_PATH)
if not input_path:
    raise FileNotFoundError(
        "Could not find 'orders_raw.csv'. Upload it next to the notebook (./orders_raw.csv) "
        "or to DBFS at dbfs:/FileStore/orders_raw.csv, then re-run."
    )
print(f"Using input_path: {input_path}")


raw_schema = T.StructType([
    T.StructField("order_id",    T.StringType(), True),
    T.StructField("customer_id", T.StringType(), True),
    T.StructField("city",        T.StringType(), True),
    T.StructField("category",    T.StringType(), True),
    T.StructField("product",     T.StringType(), True),
    T.StructField("amount",      T.StringType(), True),
    T.StructField("order_date",  T.StringType(), True),
    T.StructField("status",      T.StringType(), True),
])
df_raw = (spark.read
    .option("header", "true")
    .option("mode", "PERMISSIVE")
    .option("columnNameOfCorruptRecord", "_corrupt_record")
    .csv(input_path))


print("=== Raw Schema ===")
df_raw.printSchema()
print("=== Raw Record Count ===", df_raw.count())


string_cols = ["order_id","customer_id","city","category","product","amount","order_date","status"]
def trim_all(df, cols):
    for c in cols:
        df = df.withColumn(c, F.when(F.col(c).isNotNull(), F.trim(F.col(c))).otherwise(F.col(c)))
    return df
df1 = trim_all(df_raw, string_cols)


city_keys = ["bangalore","bengaluru","mumbai","bombay","delhi","new delhi",
             "chennai","kolkata","calcutta","hyderabad","pune"]
city_vals = ["Bangalore","Bangalore","Mumbai","Mumbai","Delhi","Delhi",
             "Chennai","Kolkata","Kolkata","Hyderabad","Pune"]
city_map = F.map_from_arrays(F.array(*[F.lit(k) for k in city_keys]),
                             F.array(*[F.lit(v) for v in city_vals]))

df2 = (df1
    .withColumn("city_lc", F.lower(F.col("city")))
    .withColumn("city_std", F.coalesce(city_map[F.col("city_lc")], F.initcap(F.col("city_lc"))))
    .withColumn("category_lc", F.lower(F.col("category")))
    .withColumn("category_std",
                F.when(F.col("category_lc").isin("electronics","grocery","fashion","home"),
                       F.initcap(F.col("category_lc")))
                 .otherwise(F.initcap(F.col("category_lc"))))
    .withColumn("product_std",
                F.initcap(F.regexp_replace(F.regexp_replace(F.col("product"), r"\s+", " "),
                                           r",+$", "")))
)


df3 = (df2
    .withColumn("amount_digits", F.regexp_replace(F.col("amount"), r"[^0-9]", ""))
    .withColumn("amount_int", F.when(F.length(F.col("amount_digits")) > 0,
                                     F.col("amount_digits").cast("int"))
                               .otherwise(F.lit(None).cast("int")))
)


date_candidates = [
    F.try_to_timestamp(F.col("order_date"), F.lit("yyyy-MM-dd")),
    F.try_to_timestamp(F.col("order_date"), F.lit("dd/MM/yyyy")),
    F.try_to_timestamp(F.col("order_date"), F.lit("yyyy/MM/dd")),
]

df4 = (df3
    .withColumn("order_ts", F.coalesce(*date_candidates))
    .withColumn("order_date_std", F.to_date("order_ts"))
)



df5 = (df4
    .withColumn("invalid_amount", F.col("amount_int").isNull())
    .withColumn("invalid_date",   F.col("order_date_std").isNull())
    .withColumn("invalid_status", ~F.array_contains(F.array(F.lit("Completed"), F.lit("Cancelled")), F.col("status")))
)

if "_corrupt_record" in df5.columns:
    df_clean = df5.withColumn(
        "is_invalid_record",
        F.col("invalid_amount") | F.col("invalid_date") | F.col("invalid_status") | F.col("_corrupt_record").isNotNull()
    )
else:
    df_clean = df5.withColumn(
        "is_invalid_record",
        F.col("invalid_amount") | F.col("invalid_date") | F.col("invalid_status")
    )

print("=== Data Quality Snapshot ===")
dq = (df_clean
      .select(
          F.count("*").alias("total_rows"),
          F.sum(F.col("invalid_amount").cast("int")).alias("invalid_amount_rows"),
          F.sum(F.col("invalid_date").cast("int")).alias("invalid_date_rows"),
          F.sum(F.col("invalid_status").cast("int")).alias("invalid_status_rows"),
          F.sum(F.col("is_invalid_record").cast("int")).alias("invalid_any_rows"),
      ))
dq.show(truncate=False)


df_dedup = df_clean.dropDuplicates(["order_id"])


pre_cnt  = df_dedup.count()
df_valid = df_dedup.filter((F.col("status") == "Completed") & (~F.col("is_invalid_record")))
post_cnt = df_valid.count()

print("Count after de-dup:", pre_cnt)
print("Count after status='Completed' & validity:", post_cnt)


df_for_aggs = df_valid.repartition("city_std").persist(StorageLevel.MEMORY_AND_DISK)
print("Materializing cache ...", df_for_aggs.count())


revenue_by_city = (df_for_aggs
    .groupBy("city_std")
    .agg(F.sum("amount_int").alias("total_revenue"))
    .orderBy(F.desc("total_revenue")))
revenue_by_city.explain(True)
revenue_by_city.show(20, truncate=False)

revenue_by_category = (df_for_aggs
    .groupBy("category_std")
    .agg(F.sum("amount_int").alias("total_revenue"))
    .orderBy(F.desc("total_revenue")))
revenue_by_category.show(20, truncate=False)

top5_products = (df_for_aggs
    .groupBy("product_std")
    .agg(F.sum("amount_int").alias("product_revenue"))
    .orderBy(F.desc("product_revenue"))
    .limit(5))
top5_products.show(truncate=False)

aov_by_city = (df_for_aggs
    .groupBy("city_std")
    .agg(F.avg("amount_int").alias("avg_order_value"))
    .orderBy(F.desc("avg_order_value")))
aov_by_city.show(20, truncate=False)


city_rank_w = Window.orderBy(F.desc("total_revenue"))
ranked_cities = revenue_by_city.withColumn("rank_revenue", F.rank().over(city_rank_w))
ranked_cities.show(truncate=False)

prod_cat_rev = (df_for_aggs
    .groupBy("category_std", "product_std")
    .agg(F.sum("amount_int").alias("product_revenue")))
prod_rank_w = Window.partitionBy("category_std").orderBy(F.desc("product_revenue"))
ranked_products_in_category = prod_cat_rev.withColumn("rank_in_category", F.rank().over(prod_rank_w))
ranked_products_in_category.show(50, truncate=False)

top_product_per_category = ranked_products_in_category.filter(F.col("rank_in_category") == 1)
top_product_per_category.show(truncate=False)


curated_out   = "./curated_orders_parquet_by_city"
analytics_out = "./analytics_orc"


(df_valid
 .select("order_id","customer_id","city_std","category_std","product_std",
         "amount_int","order_date_std","status")
 .write
 .mode("overwrite")
 .partitionBy("city_std")
 .parquet(curated_out))

(revenue_by_city.write.mode("overwrite").format("orc").save(f"{analytics_out}/revenue_by_city"))
(revenue_by_category.write.mode("overwrite").format("orc").save(f"{analytics_out}/revenue_by_category"))
(top5_products.write.mode("overwrite").format("orc").save(f"{analytics_out}/top5_products"))
(aov_by_city.write.mode("overwrite").format("orc").save(f"{analytics_out}/aov_by_city"))
(top_product_per_category.write.mode("overwrite").format("orc").save(f"{analytics_out}/top_product_per_category"))

# ------------------- Section 8 — Debugging & Reasoning ------------------------
# Why this fails:
#   df = df.filter(df.amount > 50000).show()
# - 'amount' is StringType (ingested as string); numeric comparison is invalid.
# - show() returns None, so assigning it to df sets df=None.
# Correct demo:
df_debug = df_raw.withColumn(
    "amount_int_safe",
    F.when(F.length(F.regexp_replace("amount", r"[^0-9]", "")) > 0,
           F.regexp_replace("amount", r"[^0-9]", "").cast("int"))
)
df_debug_filtered = df_debug.filter(F.col("amount_int_safe") > 50000)
df_debug_filtered.show(5, truncate=False)

df_for_aggs.unpersist()
print("Pipeline finished successfully.")
# Out:
# Using input_path: orders_raw.csv
# === Raw Schema ===
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- amount: string (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- status: string (nullable = true)
#
# === Raw Record Count === 300000
# === Data Quality Snapshot ===
# +----------+-------------------+-----------------+-------------------+----------------+
# |total_rows|invalid_amount_rows|invalid_date_rows|invalid_status_rows|invalid_any_rows|
# +----------+-------------------+-----------------+-------------------+----------------+
# |300000    |25164              |2595             |0                  |27542           |
# +----------+-------------------+-----------------+-------------------+----------------+
#
# Count after de-dup: 300000
# Count after status='Completed' & validity: 258834
# Materializing cache ... 258834
# == Parsed Logical Plan ==
# 'Sort ['total_revenue DESC NULLS LAST], true
# +- Aggregate [city_std#249], [city_std#249, sum(amount_int#254) AS total_revenue#1410L]
#    +- RepartitionByExpression [city_std#249]
#       +- Filter ((status#247 = Completed) AND NOT is_invalid_record#260)
#          +- Deduplicate [order_id#240]
#             +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, order_date_std#256, invalid_amount#257, invalid_date#258, invalid_status#259, ((invalid_amount#257 OR invalid_date#258) OR invalid_status#259) AS is_invalid_record#260]
#                +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, order_date_std#256, invalid_amount#257, invalid_date#258, NOT array_contains(array(Completed, Cancelled), status#247) AS invalid_status#259]
#                   +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, order_date_std#256, invalid_amount#257, isnull(order_date_std#256) AS invalid_date#258]
#                      +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, order_date_std#256, isnull(amount_int#254) AS invalid_amount#257]
#                         +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, to_date(order_ts#255, None, Some(Etc/UTC), true) AS order_date_std#256]
#                            +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, coalesce(try_to_timestamp(order_date#246, Some(yyyy-MM-dd), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#246, Some(dd/MM/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#246, Some(yyyy/MM/dd), TimestampType, Some(Etc/UTC), false)) AS order_ts#255]
#                               +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, CASE WHEN (length(amount_digits#253) > 0) THEN cast(amount_digits#253 as int) ELSE cast(null as int) END AS amount_int#254]
#                                  +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, regexp_replace(amount#245, [^0-9], , 1) AS amount_digits#253]
#                                     +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, initcap(regexp_replace(regexp_replace(product#244, \s+,  , 1), ,+$, , 1)) AS product_std#252]
#                                        +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, CASE WHEN category_lc#250 IN (electronics,grocery,fashion,home) THEN initcap(category_lc#250) ELSE initcap(category_lc#250) END AS category_std#251]
#                                           +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, lower(category#243) AS category_lc#250]
#                                              +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, coalesce(map_from_arrays(array(bangalore, bengaluru, mumbai, bombay, delhi, new delhi, chennai, kolkata, calcutta, hyderabad, pune), array(Bangalore, Bangalore, Mumbai, Mumbai, Delhi, Delhi, Chennai, Kolkata, Kolkata, Hyderabad, Pune))[city_lc#248], initcap(city_lc#248)) AS city_std#249]
#                                                 +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, lower(city#242) AS city_lc#248]
#                                                    +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, CASE WHEN isnotnull(status#226) THEN trim(status#226, None) ELSE status#226 END AS status#247]
#                                                       +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, CASE WHEN isnotnull(order_date#225) THEN trim(order_date#225, None) ELSE order_date#225 END AS order_date#246, status#226]
#                                                          +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, CASE WHEN isnotnull(amount#224) THEN trim(amount#224, None) ELSE amount#224 END AS amount#245, order_date#225, status#226]
#                                                             +- Project [order_id#240, customer_id#241, city#242, category#243, CASE WHEN isnotnull(product#223) THEN trim(product#223, None) ELSE product#223 END AS product#244, amount#224, order_date#225, status#226]
#                                                                +- Project [order_id#240, customer_id#241, city#242, CASE WHEN isnotnull(category#222) THEN trim(category#222, None) ELSE category#222 END AS category#243, product#223, amount#224, order_date#225, status#226]
#                                                                   +- Project [order_id#240, customer_id#241, CASE WHEN isnotnull(city#221) THEN trim(city#221, None) ELSE city#221 END AS city#242, category#222, product#223, amount#224, order_date#225, status#226]
#                                                                      +- Project [order_id#240, CASE WHEN isnotnull(customer_id#220) THEN trim(customer_id#220, None) ELSE customer_id#220 END AS customer_id#241, city#221, category#222, product#223, amount#224, order_date#225, status#226]
#                                                                         +- Project [CASE WHEN isnotnull(order_id#219) THEN trim(order_id#219, None) ELSE order_id#219 END AS order_id#240, customer_id#220, city#221, category#222, product#223, amount#224, order_date#225, status#226]
#                                                                            +- Relation [order_id#219,customer_id#220,city#221,category#222,product#223,amount#224,order_date#225,status#226] csv
#
# == Analyzed Logical Plan ==
# city_std: string, total_revenue: bigint
# Sort [total_revenue#1410L DESC NULLS LAST], true
# +- Aggregate [city_std#249], [city_std#249, sum(amount_int#254) AS total_revenue#1410L]
#    +- RepartitionByExpression [city_std#249]
#       +- Filter ((status#247 = Completed) AND NOT is_invalid_record#260)
#          +- Deduplicate [order_id#240]
#             +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, order_date_std#256, invalid_amount#257, invalid_date#258, invalid_status#259, ((invalid_amount#257 OR invalid_date#258) OR invalid_status#259) AS is_invalid_record#260]
#                +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, order_date_std#256, invalid_amount#257, invalid_date#258, NOT array_contains(array(Completed, Cancelled), status#247) AS invalid_status#259]
#                   +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, order_date_std#256, invalid_amount#257, isnull(order_date_std#256) AS invalid_date#258]
#                      +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, order_date_std#256, isnull(amount_int#254) AS invalid_amount#257]
#                         +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, to_date(order_ts#255, None, Some(Etc/UTC), true) AS order_date_std#256]
#                            +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, coalesce(try_to_timestamp(order_date#246, Some(yyyy-MM-dd), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#246, Some(dd/MM/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#246, Some(yyyy/MM/dd), TimestampType, Some(Etc/UTC), false)) AS order_ts#255]
#                               +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, CASE WHEN (length(amount_digits#253) > 0) THEN cast(amount_digits#253 as int) ELSE cast(null as int) END AS amount_int#254]
#                                  +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, regexp_replace(amount#245, [^0-9], , 1) AS amount_digits#253]
#                                     +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, initcap(regexp_replace(regexp_replace(product#244, \s+,  , 1), ,+$, , 1)) AS product_std#252]
#                                        +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, CASE WHEN category_lc#250 IN (electronics,grocery,fashion,home) THEN initcap(category_lc#250) ELSE initcap(category_lc#250) END AS category_std#251]
#                                           +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, lower(category#243) AS category_lc#250]
#                                              +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, coalesce(map_from_arrays(array(bangalore, bengaluru, mumbai, bombay, delhi, new delhi, chennai, kolkata, calcutta, hyderabad, pune), array(Bangalore, Bangalore, Mumbai, Mumbai, Delhi, Delhi, Chennai, Kolkata, Kolkata, Hyderabad, Pune))[city_lc#248], initcap(city_lc#248)) AS city_std#249]
#                                                 +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, lower(city#242) AS city_lc#248]
#                                                    +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, CASE WHEN isnotnull(status#226) THEN trim(status#226, None) ELSE status#226 END AS status#247]
#                                                       +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, CASE WHEN isnotnull(order_date#225) THEN trim(order_date#225, None) ELSE order_date#225 END AS order_date#246, status#226]
#                                                          +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, CASE WHEN isnotnull(amount#224) THEN trim(amount#224, None) ELSE amount#224 END AS amount#245, order_date#225, status#226]
#                                                             +- Project [order_id#240, customer_id#241, city#242, category#243, CASE WHEN isnotnull(product#223) THEN trim(product#223, None) ELSE product#223 END AS product#244, amount#224, order_date#225, status#226]
#                                                                +- Project [order_id#240, customer_id#241, city#242, CASE WHEN isnotnull(category#222) THEN trim(category#222, None) ELSE category#222 END AS category#243, product#223, amount#224, order_date#225, status#226]
#                                                                   +- Project [order_id#240, customer_id#241, CASE WHEN isnotnull(city#221) THEN trim(city#221, None) ELSE city#221 END AS city#242, category#222, product#223, amount#224, order_date#225, status#226]
#                                                                      +- Project [order_id#240, CASE WHEN isnotnull(customer_id#220) THEN trim(customer_id#220, None) ELSE customer_id#220 END AS customer_id#241, city#221, category#222, product#223, amount#224, order_date#225, status#226]
#                                                                         +- Project [CASE WHEN isnotnull(order_id#219) THEN trim(order_id#219, None) ELSE order_id#219 END AS order_id#240, customer_id#220, city#221, category#222, product#223, amount#224, order_date#225, status#226]
#                                                                            +- Relation [order_id#219,customer_id#220,city#221,category#222,product#223,amount#224,order_date#225,status#226] csv
#
# == Optimized Logical Plan ==
# Sort [total_revenue#1410L DESC NULLS LAST], true
# +- Aggregate [city_std#249], [city_std#249, sum(amount_int#254) AS total_revenue#1410L]
#    +- Project [city_std#249, amount_int#254]
#       +- InMemoryRelation [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, order_date_std#256, invalid_amount#257, invalid_date#258, invalid_status#259, is_invalid_record#260], StorageLevel(disk, memory, 1 replicas)
#             +- AdaptiveSparkPlan isFinalPlan=true
#                +- == Final Plan ==
#                   ResultQueryStage 2
#                   +- ShuffleQueryStage 1
#                      +- Exchange hashpartitioning(city_std#484, 200), REPARTITION_BY_COL, [plan_id=718]
#                         +- *(3) Filter ((isnotnull(status#480) AND isnotnull(is_invalid_record#506)) AND ((status#480 = Completed) AND NOT is_invalid_record#506))
#                            +- SortAggregate(key=[order_id#240], functions=[first(customer_id#241, false), first(city#242, false), first(category#243, false), first(product#244, false), first(amount#245, false), first(order_date#246, false), first(status#247, false), first(city_lc#248, false), first(city_std#249, false), first(category_lc#250, false), first(category_std#251, false), first(product_std#252, false), first(amount_digits#253, false), first(amount_int#254, false), first(order_ts#255, false), first(order_date_std#256, false), first(invalid_amount#257, false), first(invalid_date#258, false), first(invalid_status#259, false), first(is_invalid_record#260, false)], output=[order_id#240, customer_id#468, city#470, category#472, product#474, amount#476, order_date#478, status#480, city_lc#482, city_std#484, category_lc#486, category_std#488, product_std#490, amount_digits#492, amount_int#494, order_ts#496, order_date_std#498, invalid_amount#500, invalid_date#502, invalid_status#504, is_invalid_record#506])
#                               +- *(2) Sort [order_id#240 ASC NULLS FIRST], false, 0
#                                  +- AQEShuffleRead coalesced
#                                     +- ShuffleQueryStage 0
#                                        +- Exchange hashpartitioning(order_id#240, 200), ENSURE_REQUIREMENTS, [plan_id=661]
#                                           +- SortAggregate(key=[order_id#240], functions=[partial_first(customer_id#241, false), partial_first(city#242, false), partial_first(category#243, false), partial_first(product#244, false), partial_first(amount#245, false), partial_first(order_date#246, false), partial_first(status#247, false), partial_first(city_lc#248, false), partial_first(city_std#249, false), partial_first(category_lc#250, false), partial_first(category_std#251, false), partial_first(product_std#252, false), partial_first(amount_digits#253, false), partial_first(amount_int#254, false), partial_first(order_ts#255, false), partial_first(order_date_std#256, false), partial_first(invalid_amount#257, false), partial_first(invalid_date#258, false), partial_first(invalid_status#259, false), partial_first(is_invalid_record#260, false)], output=[order_id#240, first#547, valueSet#548, first#549, valueSet#550, first#551, valueSet#552, first#553, valueSet#554, first#555, valueSet#556, first#557, valueSet#558, first#559, valueSet#560, first#561, valueSet#562, first#563, valueSet#564, first#565, valueSet#566, first#567, valueSet#568, first#569, valueSet#570, ... 16 more fields])
#                                              +- *(1) Sort [order_id#240 ASC NULLS FIRST], false, 0
#                                                 +- *(1) Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, order_date_std#256, invalid_amount#257, invalid_date#258, invalid_status#259, ((invalid_amount#257 OR invalid_date#258) OR invalid_status#259) AS is_invalid_record#260]
#                                                    +- *(1) Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, order_date_std#256, invalid_amount#257, isnull(order_date_std#256) AS invalid_date#258, NOT array_contains([Completed,Cancelled], status#247) AS invalid_status#259]
#                                                       +- *(1) Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, cast(order_ts#255 as date) AS order_date_std#256, isnull(amount_int#254) AS invalid_amount#257]
#                                                          +- *(1) Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, CASE WHEN (length(amount_digits#253) > 0) THEN cast(amount_digits#253 as int) END AS amount_int#254, coalesce(gettimestamp(order_date#246, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#246, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#246, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS order_ts#255]
#                                                             +- *(1) Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, initcap(category_lc#250) AS category_std#251, initcap(regexp_replace(regexp_replace(product#244, \s+,  , 1), ,+$, , 1)) AS product_std#252, regexp_replace(amount#245, [^0-9], , 1) AS amount_digits#253]
#                                                                +- *(1) Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, coalesce(map(keys: [bangalore,bengaluru,mumbai,bombay,delhi,new delhi,chennai,kolkata,calcutta,hyderabad,pune], values: [Bangalore,Bangalore,Mumbai,Mumbai,Delhi,Delhi,Chennai,Kolkata,Kolkata,Hyderabad,Pune])[city_lc#248], initcap(city_lc#248)) AS city_std#249, lower(category#243) AS category_lc#250]
#                                                                   +- *(1) Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, lower(city#242) AS city_lc#248]
#                                                                      +- *(1) Project [CASE WHEN isnotnull(order_id#219) THEN trim(order_id#219, None) ELSE order_id#219 END AS order_id#240, CASE WHEN isnotnull(customer_id#220) THEN trim(customer_id#220, None) ELSE customer_id#220 END AS customer_id#241, CASE WHEN isnotnull(city#221) THEN trim(city#221, None) ELSE city#221 END AS city#242, CASE WHEN isnotnull(category#222) THEN trim(category#222, None) ELSE category#222 END AS category#243, CASE WHEN isnotnull(product#223) THEN trim(product#223, None) ELSE product#223 END AS product#244, CASE WHEN isnotnull(amount#224) THEN trim(amount#224, None) ELSE amount#224 END AS amount#245, CASE WHEN isnotnull(order_date#225) THEN trim(order_date#225, None) ELSE order_date#225 END AS order_date#246, CASE WHEN isnotnull(status#226) THEN trim(status#226, None) ELSE status#226 END AS status#247]
#                                                                         +- FileScan csv [order_id#219,customer_id#220,city#221,category#222,product#223,amount#224,order_date#225,status#226] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/orders_raw.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<order_id:string,customer_id:string,city:string,category:string,product:string,amount:strin...
#                +- == Initial Plan ==
#                   Exchange hashpartitioning(city_std#484, 200), REPARTITION_BY_COL, [plan_id=596]
#                   +- Filter ((isnotnull(status#480) AND isnotnull(is_invalid_record#506)) AND ((status#480 = Completed) AND NOT is_invalid_record#506))
#                      +- SortAggregate(key=[order_id#240], functions=[first(customer_id#241, false), first(city#242, false), first(category#243, false), first(product#244, false), first(amount#245, false), first(order_date#246, false), first(status#247, false), first(city_lc#248, false), first(city_std#249, false), first(category_lc#250, false), first(category_std#251, false), first(product_std#252, false), first(amount_digits#253, false), first(amount_int#254, false), first(order_ts#255, false), first(order_date_std#256, false), first(invalid_amount#257, false), first(invalid_date#258, false), first(invalid_status#259, false), first(is_invalid_record#260, false)], output=[order_id#240, customer_id#468, city#470, category#472, product#474, amount#476, order_date#478, status#480, city_lc#482, city_std#484, category_lc#486, category_std#488, product_std#490, amount_digits#492, amount_int#494, order_ts#496, order_date_std#498, invalid_amount#500, invalid_date#502, invalid_status#504, is_invalid_record#506])
#                         +- Sort [order_id#240 ASC NULLS FIRST], false, 0
#                            +- Exchange hashpartitioning(order_id#240, 200), ENSURE_REQUIREMENTS, [plan_id=592]
#                               +- SortAggregate(key=[order_id#240], functions=[partial_first(customer_id#241, false), partial_first(city#242, false), partial_first(category#243, false), partial_first(product#244, false), partial_first(amount#245, false), partial_first(order_date#246, false), partial_first(status#247, false), partial_first(city_lc#248, false), partial_first(city_std#249, false), partial_first(category_lc#250, false), partial_first(category_std#251, false), partial_first(product_std#252, false), partial_first(amount_digits#253, false), partial_first(amount_int#254, false), partial_first(order_ts#255, false), partial_first(order_date_std#256, false), partial_first(invalid_amount#257, false), partial_first(invalid_date#258, false), partial_first(invalid_status#259, false), partial_first(is_invalid_record#260, false)], output=[order_id#240, first#547, valueSet#548, first#549, valueSet#550, first#551, valueSet#552, first#553, valueSet#554, first#555, valueSet#556, first#557, valueSet#558, first#559, valueSet#560, first#561, valueSet#562, first#563, valueSet#564, first#565, valueSet#566, first#567, valueSet#568, first#569, valueSet#570, ... 16 more fields])
#                                  +- Sort [order_id#240 ASC NULLS FIRST], false, 0
#                                     +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, order_date_std#256, invalid_amount#257, invalid_date#258, invalid_status#259, ((invalid_amount#257 OR invalid_date#258) OR invalid_status#259) AS is_invalid_record#260]
#                                        +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, order_date_std#256, invalid_amount#257, isnull(order_date_std#256) AS invalid_date#258, NOT array_contains([Completed,Cancelled], status#247) AS invalid_status#259]
#                                           +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, cast(order_ts#255 as date) AS order_date_std#256, isnull(amount_int#254) AS invalid_amount#257]
#                                              +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, CASE WHEN (length(amount_digits#253) > 0) THEN cast(amount_digits#253 as int) END AS amount_int#254, coalesce(gettimestamp(order_date#246, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#246, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#246, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS order_ts#255]
#                                                 +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, initcap(category_lc#250) AS category_std#251, initcap(regexp_replace(regexp_replace(product#244, \s+,  , 1), ,+$, , 1)) AS product_std#252, regexp_replace(amount#245, [^0-9], , 1) AS amount_digits#253]
#                                                    +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, coalesce(map(keys: [bangalore,bengaluru,mumbai,bombay,delhi,new delhi,chennai,kolkata,calcutta,hyderabad,pune], values: [Bangalore,Bangalore,Mumbai,Mumbai,Delhi,Delhi,Chennai,Kolkata,Kolkata,Hyderabad,Pune])[city_lc#248], initcap(city_lc#248)) AS city_std#249, lower(category#243) AS category_lc#250]
#                                                       +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, lower(city#242) AS city_lc#248]
#                                                          +- Project [CASE WHEN isnotnull(order_id#219) THEN trim(order_id#219, None) ELSE order_id#219 END AS order_id#240, CASE WHEN isnotnull(customer_id#220) THEN trim(customer_id#220, None) ELSE customer_id#220 END AS customer_id#241, CASE WHEN isnotnull(city#221) THEN trim(city#221, None) ELSE city#221 END AS city#242, CASE WHEN isnotnull(category#222) THEN trim(category#222, None) ELSE category#222 END AS category#243, CASE WHEN isnotnull(product#223) THEN trim(product#223, None) ELSE product#223 END AS product#244, CASE WHEN isnotnull(amount#224) THEN trim(amount#224, None) ELSE amount#224 END AS amount#245, CASE WHEN isnotnull(order_date#225) THEN trim(order_date#225, None) ELSE order_date#225 END AS order_date#246, CASE WHEN isnotnull(status#226) THEN trim(status#226, None) ELSE status#226 END AS status#247]
#                                                             +- FileScan csv [order_id#219,customer_id#220,city#221,category#222,product#223,amount#224,order_date#225,status#226] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/orders_raw.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<order_id:string,customer_id:string,city:string,category:string,product:string,amount:strin...
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Sort [total_revenue#1410L DESC NULLS LAST], true, 0
#    +- Exchange rangepartitioning(total_revenue#1410L DESC NULLS LAST, 200), ENSURE_REQUIREMENTS, [plan_id=776]
#       +- HashAggregate(keys=[city_std#249], functions=[sum(amount_int#254)], output=[city_std#249, total_revenue#1410L])
#          +- HashAggregate(keys=[city_std#249], functions=[partial_sum(amount_int#254)], output=[city_std#249, sum#1749L])
#             +- InMemoryTableScan [city_std#249, amount_int#254]
#                   +- InMemoryRelation [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, order_date_std#256, invalid_amount#257, invalid_date#258, invalid_status#259, is_invalid_record#260], StorageLevel(disk, memory, 1 replicas)
#                         +- AdaptiveSparkPlan isFinalPlan=true
#                            +- == Final Plan ==
#                               ResultQueryStage 2
#                               +- ShuffleQueryStage 1
#                                  +- Exchange hashpartitioning(city_std#484, 200), REPARTITION_BY_COL, [plan_id=718]
#                                     +- *(3) Filter ((isnotnull(status#480) AND isnotnull(is_invalid_record#506)) AND ((status#480 = Completed) AND NOT is_invalid_record#506))
#                                        +- SortAggregate(key=[order_id#240], functions=[first(customer_id#241, false), first(city#242, false), first(category#243, false), first(product#244, false), first(amount#245, false), first(order_date#246, false), first(status#247, false), first(city_lc#248, false), first(city_std#249, false), first(category_lc#250, false), first(category_std#251, false), first(product_std#252, false), first(amount_digits#253, false), first(amount_int#254, false), first(order_ts#255, false), first(order_date_std#256, false), first(invalid_amount#257, false), first(invalid_date#258, false), first(invalid_status#259, false), first(is_invalid_record#260, false)], output=[order_id#240, customer_id#468, city#470, category#472, product#474, amount#476, order_date#478, status#480, city_lc#482, city_std#484, category_lc#486, category_std#488, product_std#490, amount_digits#492, amount_int#494, order_ts#496, order_date_std#498, invalid_amount#500, invalid_date#502, invalid_status#504, is_invalid_record#506])
#                                           +- *(2) Sort [order_id#240 ASC NULLS FIRST], false, 0
#                                              +- AQEShuffleRead coalesced
#                                                 +- ShuffleQueryStage 0
#                                                    +- Exchange hashpartitioning(order_id#240, 200), ENSURE_REQUIREMENTS, [plan_id=661]
#                                                       +- SortAggregate(key=[order_id#240], functions=[partial_first(customer_id#241, false), partial_first(city#242, false), partial_first(category#243, false), partial_first(product#244, false), partial_first(amount#245, false), partial_first(order_date#246, false), partial_first(status#247, false), partial_first(city_lc#248, false), partial_first(city_std#249, false), partial_first(category_lc#250, false), partial_first(category_std#251, false), partial_first(product_std#252, false), partial_first(amount_digits#253, false), partial_first(amount_int#254, false), partial_first(order_ts#255, false), partial_first(order_date_std#256, false), partial_first(invalid_amount#257, false), partial_first(invalid_date#258, false), partial_first(invalid_status#259, false), partial_first(is_invalid_record#260, false)], output=[order_id#240, first#547, valueSet#548, first#549, valueSet#550, first#551, valueSet#552, first#553, valueSet#554, first#555, valueSet#556, first#557, valueSet#558, first#559, valueSet#560, first#561, valueSet#562, first#563, valueSet#564, first#565, valueSet#566, first#567, valueSet#568, first#569, valueSet#570, ... 16 more fields])
#                                                          +- *(1) Sort [order_id#240 ASC NULLS FIRST], false, 0
#                                                             +- *(1) Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, order_date_std#256, invalid_amount#257, invalid_date#258, invalid_status#259, ((invalid_amount#257 OR invalid_date#258) OR invalid_status#259) AS is_invalid_record#260]
#                                                                +- *(1) Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, order_date_std#256, invalid_amount#257, isnull(order_date_std#256) AS invalid_date#258, NOT array_contains([Completed,Cancelled], status#247) AS invalid_status#259]
#                                                                   +- *(1) Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, cast(order_ts#255 as date) AS order_date_std#256, isnull(amount_int#254) AS invalid_amount#257]
#                                                                      +- *(1) Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, CASE WHEN (length(amount_digits#253) > 0) THEN cast(amount_digits#253 as int) END AS amount_int#254, coalesce(gettimestamp(order_date#246, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#246, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#246, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS order_ts#255]
#                                                                         +- *(1) Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, initcap(category_lc#250) AS category_std#251, initcap(regexp_replace(regexp_replace(product#244, \s+,  , 1), ,+$, , 1)) AS product_std#252, regexp_replace(amount#245, [^0-9], , 1) AS amount_digits#253]
#                                                                            +- *(1) Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, coalesce(map(keys: [bangalore,bengaluru,mumbai,bombay,delhi,new delhi,chennai,kolkata,calcutta,hyderabad,pune], values: [Bangalore,Bangalore,Mumbai,Mumbai,Delhi,Delhi,Chennai,Kolkata,Kolkata,Hyderabad,Pune])[city_lc#248], initcap(city_lc#248)) AS city_std#249, lower(category#243) AS category_lc#250]
#                                                                               +- *(1) Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, lower(city#242) AS city_lc#248]
#                                                                                  +- *(1) Project [CASE WHEN isnotnull(order_id#219) THEN trim(order_id#219, None) ELSE order_id#219 END AS order_id#240, CASE WHEN isnotnull(customer_id#220) THEN trim(customer_id#220, None) ELSE customer_id#220 END AS customer_id#241, CASE WHEN isnotnull(city#221) THEN trim(city#221, None) ELSE city#221 END AS city#242, CASE WHEN isnotnull(category#222) THEN trim(category#222, None) ELSE category#222 END AS category#243, CASE WHEN isnotnull(product#223) THEN trim(product#223, None) ELSE product#223 END AS product#244, CASE WHEN isnotnull(amount#224) THEN trim(amount#224, None) ELSE amount#224 END AS amount#245, CASE WHEN isnotnull(order_date#225) THEN trim(order_date#225, None) ELSE order_date#225 END AS order_date#246, CASE WHEN isnotnull(status#226) THEN trim(status#226, None) ELSE status#226 END AS status#247]
#                                                                                     +- FileScan csv [order_id#219,customer_id#220,city#221,category#222,product#223,amount#224,order_date#225,status#226] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/orders_raw.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<order_id:string,customer_id:string,city:string,category:string,product:string,amount:strin...
#                            +- == Initial Plan ==
#                               Exchange hashpartitioning(city_std#484, 200), REPARTITION_BY_COL, [plan_id=596]
#                               +- Filter ((isnotnull(status#480) AND isnotnull(is_invalid_record#506)) AND ((status#480 = Completed) AND NOT is_invalid_record#506))
#                                  +- SortAggregate(key=[order_id#240], functions=[first(customer_id#241, false), first(city#242, false), first(category#243, false), first(product#244, false), first(amount#245, false), first(order_date#246, false), first(status#247, false), first(city_lc#248, false), first(city_std#249, false), first(category_lc#250, false), first(category_std#251, false), first(product_std#252, false), first(amount_digits#253, false), first(amount_int#254, false), first(order_ts#255, false), first(order_date_std#256, false), first(invalid_amount#257, false), first(invalid_date#258, false), first(invalid_status#259, false), first(is_invalid_record#260, false)], output=[order_id#240, customer_id#468, city#470, category#472, product#474, amount#476, order_date#478, status#480, city_lc#482, city_std#484, category_lc#486, category_std#488, product_std#490, amount_digits#492, amount_int#494, order_ts#496, order_date_std#498, invalid_amount#500, invalid_date#502, invalid_status#504, is_invalid_record#506])
#                                     +- Sort [order_id#240 ASC NULLS FIRST], false, 0
#                                        +- Exchange hashpartitioning(order_id#240, 200), ENSURE_REQUIREMENTS, [plan_id=592]
#                                           +- SortAggregate(key=[order_id#240], functions=[partial_first(customer_id#241, false), partial_first(city#242, false), partial_first(category#243, false), partial_first(product#244, false), partial_first(amount#245, false), partial_first(order_date#246, false), partial_first(status#247, false), partial_first(city_lc#248, false), partial_first(city_std#249, false), partial_first(category_lc#250, false), partial_first(category_std#251, false), partial_first(product_std#252, false), partial_first(amount_digits#253, false), partial_first(amount_int#254, false), partial_first(order_ts#255, false), partial_first(order_date_std#256, false), partial_first(invalid_amount#257, false), partial_first(invalid_date#258, false), partial_first(invalid_status#259, false), partial_first(is_invalid_record#260, false)], output=[order_id#240, first#547, valueSet#548, first#549, valueSet#550, first#551, valueSet#552, first#553, valueSet#554, first#555, valueSet#556, first#557, valueSet#558, first#559, valueSet#560, first#561, valueSet#562, first#563, valueSet#564, first#565, valueSet#566, first#567, valueSet#568, first#569, valueSet#570, ... 16 more fields])
#                                              +- Sort [order_id#240 ASC NULLS FIRST], false, 0
#                                                 +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, order_date_std#256, invalid_amount#257, invalid_date#258, invalid_status#259, ((invalid_amount#257 OR invalid_date#258) OR invalid_status#259) AS is_invalid_record#260]
#                                                    +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, order_date_std#256, invalid_amount#257, isnull(order_date_std#256) AS invalid_date#258, NOT array_contains([Completed,Cancelled], status#247) AS invalid_status#259]
#                                                       +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, amount_int#254, order_ts#255, cast(order_ts#255 as date) AS order_date_std#256, isnull(amount_int#254) AS invalid_amount#257]
#                                                          +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, category_std#251, product_std#252, amount_digits#253, CASE WHEN (length(amount_digits#253) > 0) THEN cast(amount_digits#253 as int) END AS amount_int#254, coalesce(gettimestamp(order_date#246, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#246, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#246, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS order_ts#255]
#                                                             +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, city_std#249, category_lc#250, initcap(category_lc#250) AS category_std#251, initcap(regexp_replace(regexp_replace(product#244, \s+,  , 1), ,+$, , 1)) AS product_std#252, regexp_replace(amount#245, [^0-9], , 1) AS amount_digits#253]
#                                                                +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, city_lc#248, coalesce(map(keys: [bangalore,bengaluru,mumbai,bombay,delhi,new delhi,chennai,kolkata,calcutta,hyderabad,pune], values: [Bangalore,Bangalore,Mumbai,Mumbai,Delhi,Delhi,Chennai,Kolkata,Kolkata,Hyderabad,Pune])[city_lc#248], initcap(city_lc#248)) AS city_std#249, lower(category#243) AS category_lc#250]
#                                                                   +- Project [order_id#240, customer_id#241, city#242, category#243, product#244, amount#245, order_date#246, status#247, lower(city#242) AS city_lc#248]
#                                                                      +- Project [CASE WHEN isnotnull(order_id#219) THEN trim(order_id#219, None) ELSE order_id#219 END AS order_id#240, CASE WHEN isnotnull(customer_id#220) THEN trim(customer_id#220, None) ELSE customer_id#220 END AS customer_id#241, CASE WHEN isnotnull(city#221) THEN trim(city#221, None) ELSE city#221 END AS city#242, CASE WHEN isnotnull(category#222) THEN trim(category#222, None) ELSE category#222 END AS category#243, CASE WHEN isnotnull(product#223) THEN trim(product#223, None) ELSE product#223 END AS product#244, CASE WHEN isnotnull(amount#224) THEN trim(amount#224, None) ELSE amount#224 END AS amount#245, CASE WHEN isnotnull(order_date#225) THEN trim(order_date#225, None) ELSE order_date#225 END AS order_date#246, CASE WHEN isnotnull(status#226) THEN trim(status#226, None) ELSE status#226 END AS status#247]
#                                                                         +- FileScan csv [order_id#219,customer_id#220,city#221,category#222,product#223,amount#224,order_date#225,status#226] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/orders_raw.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<order_id:string,customer_id:string,city:string,category:string,product:string,amount:strin...
#
# +---------+-------------+
# |city_std |total_revenue|
# +---------+-------------+
# |Pune     |1631286681   |
# |Hyderabad|1629316412   |
# |Delhi    |1623209640   |
# |Chennai  |1614928816   |
# |Bangalore|1614502422   |
# |Mumbai   |1612372385   |
# |Kolkata  |1610016642   |
# +---------+-------------+
#
# +------------+-------------+
# |category_std|total_revenue|
# +------------+-------------+
# |Home        |2842762769   |
# |Electronics |2842335554   |
# |Grocery     |2841412668   |
# |Fashion     |2809122007   |
# +------------+-------------+
#
# +-----------+---------------+
# |product_std|product_revenue|
# +-----------+---------------+
# |Oil        |955294283      |
# |Laptop     |955061707      |
# |Tablet     |951653603      |
# |Vacuum     |950475394      |
# |Mixer      |948801483      |
# +-----------+---------------+
#
# +---------+------------------+
# |city_std |avg_order_value   |
# +---------+------------------+
# |Bangalore|44089.20019661924 |
# |Pune     |43917.90547598535 |
# |Delhi    |43792.414611773595|
# |Mumbai   |43722.981397619114|
# |Kolkata  |43719.56340628904 |
# |Hyderabad|43718.91198883761 |
# |Chennai  |43606.65377760976 |
# +---------+------------------+
#
# +---------+-------------+------------+
# |city_std |total_revenue|rank_revenue|
# +---------+-------------+------------+
# |Pune     |1631286681   |1           |
# |Hyderabad|1629316412   |2           |
# |Delhi    |1623209640   |3           |
# |Chennai  |1614928816   |4           |
# |Bangalore|1614502422   |5           |
# |Mumbai   |1612372385   |6           |
# |Kolkata  |1610016642   |7           |
# +---------+-------------+------------+
#
# +------------+-----------+---------------+----------------+
# |category_std|product_std|product_revenue|rank_in_category|
# +------------+-----------+---------------+----------------+
# |Electronics |Laptop     |955061707      |1               |
# |Electronics |Tablet     |951653603      |2               |
# |Electronics |Mobile     |935620244      |3               |
# |Fashion     |Jeans      |942574809      |1               |
# |Fashion     |Shoes      |937880299      |2               |
# |Fashion     |Tshirt     |928666899      |3               |
# |Grocery     |Oil        |955294283      |1               |
# |Grocery     |Rice       |945818225      |2               |
# |Grocery     |Sugar      |940300160      |3               |
# |Home        |Vacuum     |950475394      |1               |
# |Home        |Mixer      |948801483      |2               |
# |Home        |Airpurifier|943485892      |3               |
# +------------+-----------+---------------+----------------+
#
# +------------+-----------+---------------+----------------+
# |category_std|product_std|product_revenue|rank_in_category|
# +------------+-----------+---------------+----------------+
# |Electronics |Laptop     |955061707      |1               |
# |Fashion     |Jeans      |942574809      |1               |
# |Grocery     |Oil        |955294283      |1               |
# |Home        |Vacuum     |950475394      |1               |
# +------------+-----------+---------------+----------------+
#
# +-----------+-----------+---------+-----------+-------+------+----------+---------+---------------+
# |order_id   |customer_id|city     |category   |product|amount|order_date|status   |amount_int_safe|
# +-----------+-----------+---------+-----------+-------+------+----------+---------+---------------+
# |ORD00000002|C000002    |Pune     |Electronics|Mobile |65358 |2024-01-03|Completed|65358          |
# |ORD00000009|C000009    |Kolkata  |Electronics|Laptop |63715 |2024-01-10|Completed|63715          |
# |ORD00000010|C000010    |Bangalore|Grocery    |Sugar  |66576 |2024-01-11|Completed|66576          |
# |ORD00000011|C000011    |Kolkata  |Electronics|Tablet |50318 |12/01/2024|Completed|50318          |
# |ORD00000012|C000012    |Bangalore|Grocery    |Sugar  |84768 |2024-01-13|Completed|84768          |
# +-----------+-----------+---------+-----------+-------+------+----------+---------+---------------+
# only showing top 5 rows
# Pipeline finished successfully.
